# %% [markdown]
# ## Week 12 Assignment
# ### The New York Times web site provides a rich set of APIs, as described here: http://developer.nytimes.com/docs
# ### Your task is to choose one of the New York Times APIs, construct an interface in Python to read in the JSON data, and transform it into a pandas DataFrame.

# %%
#import modules
import requests, json
import urllib.request
from urllib.request import urlopen
import pandas as pd

#access url and provide api key
api_key = 'b7faf362029a4dedbe1ca1f9133bd66a'
url = 'https://api.nytimes.com/svc/books/v3/lists/best-sellers/history.json?'
string = url+'&api-key='+api_key

#process data from json to a dataframe
response = str(urllib.request.urlopen(string).read(), 'utf-8')
books = pd.read_json(response)
newset = books['results']
books
# Out:
#                                             copyright  num_results  \
# 0   Copyright (c) 2018 The New York Times Company....        31252
# 1   Copyright (c) 2018 The New York Times Company....        31252
# 2   Copyright (c) 2018 The New York Times Company....        31252
# 3   Copyright (c) 2018 The New York Times Company....        31252
# 4   Copyright (c) 2018 The New York Times Company....        31252
# 5   Copyright (c) 2018 The New York Times Company....        31252
# 6   Copyright (c) 2018 The New York Times Company....        31252
# 7   Copyright (c) 2018 The New York Times Company....        31252
# 8   Copyright (c) 2018 The New York Times Company....        31252
# 9   Copyright (c) 2018 The New York Times Company....        31252
# 10  Copyright (c) 2018 The New York Times Company....        31252
# 11  Copyright (c) 2018 The New York Times Company....        31252
# 12  Copyright (c) 2018 The New York Times Company....        31252
# 13  Copyright (c) 2018 The New York Times Company....        31252
# 14  Copyright (c) 2018 The New York Times Company....        31252
# 15  Copyright (c) 2018 The New York Times Company....        31252
# 16  Copyright (c) 2018 The New York Times Company....        31252
# 17  Copyright (c) 2018 The New York Times Company....        31252
# 18  Copyright (c) 2018 The New York Times Company....        31252
# 19  Copyright (c) 2018 The New York Times Company....        31252
#
#                                               results status
# 0   {'title': '"I GIVE YOU MY BODY ..."', 'descrip...     OK
# 1   {'title': '"MOST BLESSED OF THE PATRIARCHS"', ...     OK
# 2   {'title': '#ASKGARYVEE', 'description': 'The e...     OK
# 3   {'title': '#GIRLBOSS', 'description': 'An onli...     OK
# 4   {'title': '$100 STARTUP', 'description': 'How ...     OK
# 5   {'title': '$20 PER GALLON', 'description': '',...     OK
# 6   {'title': ''57, Chicago', 'description': None,...     OK
# 7   {'title': ''ROCK OF AGES: ''ROLLING STONE'' HI...     OK
# 8   {'title': ''THE HIGH ROAD TO CHINA: GEORGE BOG...     OK
# 9   {'title': ''TIL DEATH', 'description': '', 'co...     OK
# 10  {'title': ''TIL DEATH DO US PART', 'descriptio...     OK
# 11  {'title': ''Til Faith Do Us Part: How Interfai...     OK
# 12  {'title': ''TIS THE SEASON', 'description': 'T...     OK
# 13  {'title': '------, THAT'S DELICIOUS', 'descrip...     OK
# 14  {'title': '...and the Horse He Rode In On: The...     OK
# 15  {'title': '.HACK G.U.   , VOL. 5', 'descriptio...     OK
# 16  {'title': '1 Ragged Ridge Road', 'description'...     OK
# 17  {'title': '1,000 PLACES TO SEE BEFORE YOU DIE'...     OK
# 18  {'title': '1,000 RECORDINGS TO HEAR BEFORE YOU...     OK
# 19  {'title': '1,227 QUITE INTERESTING FACTS TO BL...     OK
